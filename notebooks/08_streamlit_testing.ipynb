# %% [markdown]
# # Streamlit Deployment
#
# ## Objective
#
# Build an interactive customer churn prediction application.

# %% [markdown]
# ## 1. Import Libraries
#
# ### Objective
#
# Import libraries required for deployment.

# %%
import streamlit as st
import pandas as pd
import joblib

# %% [markdown]
# ## 2. Load Model
#
# ### Objective
#
# Load saved model and preprocessing objects.

# %%
model = joblib.load("../models/logistic_regression.pkl")
scaler = joblib.load("../models/scaler.pkl")

# %%
model
# Out:
# LogisticRegression(random_state=42)

# %%
scaler
# Out:
# StandardScaler()

# %% [markdown]
# ### Observation
#
# - Model loaded successfully.
# - Scaler loaded successfully.

# %% [markdown]
# ## 3. Test Prediction
#
# ### Objective
#
# Verify model prediction using test data.

# %%
X_test = pd.read_csv("../data/processed/X_test.csv")

# %%
sample = X_test.iloc[[0]]

# %%
prediction = model.predict(sample)

prediction
# Out:
# array([0])

# %%
model.predict_proba(sample)
# Out:
# array([[0.99424589, 0.00575411]])

# %% [markdown]
# ## 4. Prediction Result

# %%
if prediction[0] == 1:
    print("Customer is likely to Churn.")
else:
    print("Customer is likely to Stay.")
# Out:
# Customer is likely to Stay.

# %% [markdown]
# ### Observation
#
# - Saved model tested successfully.
# - Predictions generated correctly.
